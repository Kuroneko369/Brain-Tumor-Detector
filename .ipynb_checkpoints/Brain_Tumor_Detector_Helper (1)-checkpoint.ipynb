# %% [markdown]
# # Brain Tumor Detector

# %% [markdown]
# ## Get and Load Dataset

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras import layers, models
from tensorflow import keras

# %%
# !pip install --upgrade --no-cache-dir gdowna
# Out:
# ERROR: Could not find a version that satisfies the requirement gdowna (from versions: none)
# ERROR: No matching distribution found for gdowna

# %%
# !gdown --id 1bXBSfKDaItFigHa5QfcnyTXADG2wlWJj
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1bXBSfKDaItFigHa5QfcnyTXADG2wlWJj
# From (redirected): https://drive.google.com/uc?id=1bXBSfKDaItFigHa5QfcnyTXADG2wlWJj&confirm=t&uuid=9b80dda2-3017-44da-9996-ae634c88adec
# To: /content/brain_tumor.zip
# 100% 156M/156M [00:04<00:00, 37.6MB/s]

# %%
# !unzip -q brain_tumor.zip

# %%
ls -l
# Out:
# total 152156
# -rw-r--r-- 1 root root 155791278 Apr  5 07:14 brain_tumor.zip
# drwxr-xr-x 1 root root      4096 Apr  3 13:25 sample_data/
# drwxr-xr-x 6 root root      4096 Apr  5 07:14 Testing/
# drwxr-xr-x 6 root root      4096 Apr  5 07:14 Training/

# %%
# !sudo apt-get install tree #just to see folder structures, run only on linux systems like colab
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (53.9 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# (Reading database ... 121753 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree --dirsfirst --filelimit 4 ./Training/ #just to see folder structures, run only on linux systems like colab
# Out:
# ./Training/
# ├── glioma  [1321 entries exceeds filelimit, not opening dir]
# ├── meningioma  [1339 entries exceeds filelimit, not opening dir]
# ├── notumor  [1595 entries exceeds filelimit, not opening dir]
# └── pituitary  [1457 entries exceeds filelimit, not opening dir]
#
# 4 directories, 0 files

# %%
# !tree --dirsfirst --filelimit 4 ./Testing/ #just to see folder structures, run only on linux systems like colab
# Out:
# ./Testing/
# ├── glioma  [300 entries exceeds filelimit, not opening dir]
# ├── meningioma  [306 entries exceeds filelimit, not opening dir]
# ├── notumor  [405 entries exceeds filelimit, not opening dir]
# └── pituitary  [300 entries exceeds filelimit, not opening dir]
#
# 4 directories, 0 files

# %% [markdown]
# ## Load Dependencies

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix,\
                            classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm
from glob import glob

print('TF Version:', tf.__version__)
# Out:
# TF Version: 2.15.0

# %% [markdown]
# ## Utility functions to create dataset generators

# %%
IMG_DIMS = (128, 128)
BATCH_SIZE = 32
IMG_SHAPE = IMG_DIMS + (3,)
classes = ['glioma', 'meningioma', 'notumor', 'pituitary']

# call this function before running any model to get data into train and validation splits
# data is loaded as a TF dataset in a memory efficient format
def prepare_train_and_val_datasets():
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="training",
        class_names=['glioma', 'meningioma', 'notumor', 'pituitary'],
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="validation",
        class_names=['glioma', 'meningioma', 'notumor', 'pituitary'],
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    train_ds = train_ds.prefetch(buffer_size=25)
    val_ds = val_ds.prefetch(buffer_size=25)

    return train_ds, val_ds

# call this function on any trained model to get prediction labels on the test data
# this loads the test dataset from the test directory as a test dataset
# iterates through the above dataset and returns the true labels as well as the predicted labels
def eval_model_on_test(model):
    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Testing",
        class_names=['glioma', 'meningioma', 'notumor', 'pituitary'],
        seed=42,
        image_size=IMG_DIMS,
        batch_size=128,
    )

    test_labels = []
    predictions = []

    for imgs, labels in tqdm(test_ds.take(100),
                             desc='Predicting on Test Data'):
        batch_preds = model.predict(imgs)
        predictions.extend(batch_preds)
        test_labels.extend(labels)

    predictions = np.array(predictions)
    test_labels = np.array(test_labels)

    return test_labels, predictions

# %% [markdown]
# ### Example usage of the above functions
#
# ```
# train_ds, val_ds = prepare_train_and_val_datasets()
#
# model = <BIG CNN MODEL>
#
# history = model.fit(
#     train_ds, epochs=10,
#     validation_data=val_ds,
# )
#
# y_true, y_pred = eval_model_on_test(model)

# %%
train_ds, val_ds = prepare_train_and_val_datasets()
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %%
plt.figure(figsize=(12, 6))

for images, labels in train_ds.take(2):
    for i in range(8):
        ax = plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
plt.tight_layout()

# %% [markdown]
# ## If you want to apply data augmentation operations on the train dataset
#
# Go to the `prepare_train_and_val_datasets(...)` and you can add augmentation operations directly to the train dataset as follows:
#
# ```
# train_ds = (train_ds.map(lambda image, label: (tf.image.random_flip_left_right(image), label))
#                     .map(lambda image, label: (tf.image.random_contrast(image, lower=0.2, upper=1.5), label))
#                         .shuffle(2000)
#                         .prefetch(buffer_size=tf.data.AUTOTUNE))
# ```
#
#
# Remember to check [`tf.image`](https://www.tensorflow.org/api_docs/python/tf/image#image_adjustments) for various image transforms available and you can play around with augmentations
#
# __Be careful here and don't add too many transforms which can distort the images beyond recognition__

# %%
train_ds = (train_ds.map(lambda image, label: (tf.image.random_flip_left_right(image), label))
                    .map(lambda image, label: (tf.image.random_contrast(image, lower=0.2, upper=1.5), label))
                        .shuffle(2000)
                        .prefetch(buffer_size=tf.data.AUTOTUNE))

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(len(train_ds))
# Out:
# 143

# %%
# here comes the model

# %%
train_ds, val_ds = prepare_train_and_val_datasets()  # load and preprocess the train and validation datasets
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %%
#y_true, y_pred = eval_model_on_test(model)

# %%
y_pred_class = np.argmax(y_pred,1)

# %%
y_pred_class.shape

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].plot(history.history['sparse_categorical_accuracy'], label='accuracy')
ax[0].plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='lower right');

ax[1].plot(history.history['loss'], label='loss')
ax[1].plot(history.history['val_loss'], label = 'val_loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='upper right');

fig.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
class_names=['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
print(classification_report(y_true, y_pred_class, target_names=class_names))

# %%
print(confusion_matrix(y_true, y_pred_class))

# %%
plt.subplots(figsize=(4,3.5))
sns.heatmap(confusion_matrix(y_true, y_pred_class), annot=True, fmt=".0f");
plt.show()

# %%
# basic solution cnn from scratch

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

IMG_DIMS = (128, 128)
BATCH_SIZE = 32
NUM_CLASSES = 4
EPOCHS = 30

# %%
def prepare_data():
    train_ds, val_ds = prepare_train_val_dataset()
    return train_ds, val_ds

def prepare_train_val_dataset():
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="training",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="validation",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    return train_ds, val_ds

def create_model():
    model = Sequential([
        Conv2D(16, 3, padding='same', activation='relu', input_shape=IMG_SHAPE),
        MaxPooling2D(),
        Conv2D(32, 3, padding='same', activation='relu'),
        MaxPooling2D(),

        Flatten(),
        Dense(NUM_CLASSES) # Output layer has size equal to the number of classes
    ])

    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['sparse_categorical_accuracy'])

    return model

def train_model():
    train_ds, val_ds = prepare_data()
    model = create_model()
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)

if __name__ == "__main__":
    train_model()
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.
# Epoch 1/30
# 143/143 [==============================] - 11s 45ms/step - loss: 14.1275 - sparse_categorical_accuracy: 0.6816 - val_loss: 0.5111 - val_sparse_categorical_accuracy: 0.8406
# Epoch 2/30
# 143/143 [==============================] - 8s 54ms/step - loss: 0.3402 - sparse_categorical_accuracy: 0.8917 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.9046
# Epoch 3/30
# 143/143 [==============================] - 6s 40ms/step - loss: 0.1903 - sparse_categorical_accuracy: 0.9383 - val_loss: 0.2937 - val_sparse_categorical_accuracy: 0.9238
# Epoch 4/30
# 143/143 [==============================] - 6s 41ms/step - loss: 0.1084 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.3079 - val_sparse_categorical_accuracy: 0.9212
# Epoch 5/30
# 143/143 [==============================] - 7s 47ms/step - loss: 0.0683 - sparse_categorical_accuracy: 0.9814 - val_loss: 0.3380 - val_sparse_categorical_accuracy: 0.9299
# Epoch 6/30
# 143/143 [==============================] - 6s 39ms/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.4019 - val_sparse_categorical_accuracy: 0.9221
# Epoch 7/30
# 143/143 [==============================] - 7s 48ms/step - loss: 0.0930 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.4085 - val_sparse_categorical_accuracy: 0.9098
# Epoch 8/30
# 143/143 [==============================] - 7s 49ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9856 - val_loss: 0.4290 - val_sparse_categorical_accuracy: 0.9177
# Epoch 9/30
# 143/143 [==============================] - 6s 40ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.4560 - val_sparse_categorical_accuracy: 0.9124
# Epoch 10/30
# 143/143 [==============================] - 7s 48ms/step - loss: 0.0079 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.4464 - val_sparse_categorical_accuracy: 0.9247
# Epoch 11/30
# 143/143 [==============================] - 6s 41ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9998 - val_loss: 0.4677 - val_sparse_categorical_accuracy: 0.9256
# Epoch 12/30
# 143/143 [==============================] - 6s 39ms/step - loss: 0.0015 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4849 - val_sparse_categorical_accuracy: 0.9264
# Epoch 13/30
# 143/143 [==============================] - 6s 39ms/step - loss: 0.0010 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4912 - val_sparse_categorical_accuracy: 0.9282
# Epoch 14/30
# 143/143 [==============================] - 8s 52ms/step - loss: 7.7523e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5024 - val_sparse_categorical_accuracy: 0.9282
# Epoch 15/30
# 143/143 [==============================] - 6s 41ms/step - loss: 6.2558e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5142 - val_sparse_categorical_accuracy: 0.9291
# Epoch 16/30
# 143/143 [==============================] - 7s 47ms/step - loss: 5.0493e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5232 - val_sparse_categorical_accuracy: 0.9291
# Epoch 17/30
# 143/143 [==============================] - 7s 49ms/step - loss: 4.2521e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5313 - val_sparse_categorical_accuracy: 0.9282
# Epoch 18/30
# 143/143 [==============================] - 7s 49ms/step - loss: 3.6757e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5421 - val_sparse_categorical_accuracy: 0.9291
# Epoch 19/30
# 143/143 [==============================] - 6s 38ms/step - loss: 3.0561e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5495 - val_sparse_categorical_accuracy: 0.9273
# Epoch 20/30
# 143/143 [==============================] - 6s 42ms/step - loss: 2.6760e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5581 - val_sparse_categorical_accuracy: 0.9247
# Epoch 21/30
# 143/143 [==============================] - 7s 49ms/step - loss: 2.2818e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5662 - val_sparse_categorical_accuracy: 0.9247
# Epoch 22/30
# 143/143 [==============================] - 6s 39ms/step - loss: 2.0076e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5735 - val_sparse_categorical_accuracy: 0.9238
# Epoch 23/30
# 143/143 [==============================] - 7s 48ms/step - loss: 1.7798e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5810 - val_sparse_categorical_accuracy: 0.9229
# Epoch 24/30
# 143/143 [==============================] - 6s 41ms/step - loss: 1.5588e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5872 - val_sparse_categorical_accuracy: 0.9229
# Epoch 25/30
# 143/143 [==============================] - 7s 49ms/step - loss: 1.4039e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5939 - val_sparse_categorical_accuracy: 0.9229
# Epoch 26/30
# 143/143 [==============================] - 6s 39ms/step - loss: 1.2360e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6016 - val_sparse_categorical_accuracy: 0.9229
# Epoch 27/30
# 143/143 [==============================] - 6s 41ms/step - loss: 1.1078e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6092 - val_sparse_categorical_accuracy: 0.9229
# Epoch 28/30
# 143/143 [==============================] - 7s 50ms/step - loss: 9.8200e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6159 - val_sparse_categorical_accuracy: 0.9229
# Epoch 29/30
# 143/143 [==============================] - 6s 39ms/step - loss: 8.7859e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6225 - val_sparse_categorical_accuracy: 0.9247
# Epoch 30/30
# 143/143 [==============================] - 6s 39ms/step - loss: 7.8416e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.6294 - val_sparse_categorical_accuracy: 0.9247

# %%
y_true, y_pred = eval_model_on_test(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-68214932f212> in <cell line: 1>()
# ----> 1 y_true, y_pred = eval_model_on_test(model)
#
# NameError: name 'model' is not defined

# %%
y_pred_class = np.argmax(y_pred,1)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right');

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].plot(history.history['accuracy'], label='accuracy')
ax[0].plot(history.history['val_accuracy'], label = 'val_accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='lower right');

ax[1].plot(history.history['loss'], label='loss')
ax[1].plot(history.history['val_loss'], label = 'val_loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='upper right');

fig.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
class_names=['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
print(classification_report(y_true, y_pred_class, target_names=class_names))

# %%
print(confusion_matrix(y_true, y_pred_class))

# %%
plt.subplots(figsize=(4,3.5))
sns.heatmap(confusion_matrix(y_true, y_pred_class), annot=True, fmt=".0f");
plt.show()

# %%
'''
#EfficientNetB0
from tensorflow.keras.applications import EfficientNetB0
model = EfficientNetB0(weights='imagenet')
'''

# %%
'''


def prepare_data():
    train_ds, val_ds = prepare_train_val_dataset()
    return train_ds, val_ds

def prepare_train_val_dataset():
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="training",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="validation",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    return train_ds, val_ds

def create_model():
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    base_model.trainable = False # Freeze the base model by not training it

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(1024, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax'), # Output layer has size equal to the number of classes

        Flatten(),
        Dense(NUM_CLASSES) # Output layer has size equal to the number of classes
    ])

    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    return model

def train_model():
    train_ds, val_ds = prepare_data()
    model = create_model()
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)

if __name__ == "__main__":
    train_model()

'''

# %%
'''
def build_model(num_classes):
    inputs = layers.Input(shape=IMG_SHAPE)
    model = EfficientNetB0(include_top=False, input_tensor=inputs, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )
    return model
    '''

# %%
'''
model = build_model(num_classes=NUM_CLASSES)


history = model.fit(train_ds, epochs=EPOCHS, validation_data=val_ds)
'''

# %%
'''
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
base_model.trainable = False # Freeze the base model by not training it

model2 = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(1024, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax') # Output layer has size equal to the number of classes
    ])
# Compile the model
model2.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
'''

# %%
model.summary()

# %%
NUM_CLASSES

# %%
#hist = model2.fit(train_ds, epochs=EPOCHS, validation_data=val_ds)

# %%
#resnet model working
def create_model1():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    base_model.trainable = False # Freeze the base model by not training it

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(1024, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax') # Output layer has size equal to the number of classes
    ])

   # Compile the model
    model.compile(optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

    return model

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-5f15418b3570> in <cell line: 1>()
# ----> 1 model.summary()
#
# NameError: name 'model' is not defined

# %%
    model = create_model1()
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-843cc0d55c8f> in <cell line: 1>()
# ----> 1 model = create_model1()
#       2 history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)
#       3
#
# <ipython-input-21-09430e7a691f> in create_model1()
#       4     base_model.trainable = False # Freeze the base model by not training it
#       5
# ----> 6     model = Sequential([
#       7         base_model,
#       8         GlobalAveragePooling2D(),
#
# NameError: name 'Sequential' is not defined

# %%
model.summary()

# %%
# results
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
y_true, y_pred = eval_model_on_test(model)

# %%
y_pred_class = np.argmax(y_pred,1)

# %%
print(history.history.keys())

# %%
class_names=['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].plot(history.history['accuracy'], label='accuracy')
ax[0].plot(history.history['val_accuracy'], label = 'val_accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='lower right');

ax[1].plot(history.history['loss'], label='loss')
ax[1].plot(history.history['val_loss'], label = 'val_loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='upper right');

fig.tight_layout()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right');

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right');

# %%
print(classification_report(y_true, y_pred_class, target_names=class_names))

# %%
print(confusion_matrix(y_true, y_pred_class))

# %%
sns.heatmap(confusion_matrix(y_true, y_pred_class), annot=True);
