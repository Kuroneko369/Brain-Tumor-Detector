# %% [markdown]
# # Brain Tumor Detector

# %% [markdown]
# ## Get and Load Dataset

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras import layers, models
from tensorflow import keras

# %%
# !pip install --upgrade --no-cache-dir gdowna
# Out:
# ERROR: Could not find a version that satisfies the requirement gdowna (from versions: none)
# ERROR: No matching distribution found for gdowna

# %%
# !gdown --id 1bXBSfKDaItFigHa5QfcnyTXADG2wlWJj
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1bXBSfKDaItFigHa5QfcnyTXADG2wlWJj
# From (redirected): https://drive.google.com/uc?id=1bXBSfKDaItFigHa5QfcnyTXADG2wlWJj&confirm=t&uuid=f8c0ccfa-590f-433d-9e12-7e1a06eaeb69
# To: /content/brain_tumor.zip
# 100% 156M/156M [00:02<00:00, 67.0MB/s]

# %%
# !unzip -q brain_tumor.zip

# %%
ls -l
# Out:
# total 152156
# -rw-r--r-- 1 root root 155791278 Apr  4 18:16 brain_tumor.zip
# drwxr-xr-x 1 root root      4096 Apr  3 13:25 sample_data/
# drwxr-xr-x 6 root root      4096 Apr  4 18:16 Testing/
# drwxr-xr-x 6 root root      4096 Apr  4 18:16 Training/

# %%
# !sudo apt-get install tree #just to see folder structures, run only on linux systems like colab
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (158 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tree.
# (Reading database ... 121753 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree --dirsfirst --filelimit 4 ./Training/ #just to see folder structures, run only on linux systems like colab
# Out:
# ./Training/
# ├── glioma  [1321 entries exceeds filelimit, not opening dir]
# ├── meningioma  [1339 entries exceeds filelimit, not opening dir]
# ├── notumor  [1595 entries exceeds filelimit, not opening dir]
# └── pituitary  [1457 entries exceeds filelimit, not opening dir]
#
# 4 directories, 0 files

# %%
# !tree --dirsfirst --filelimit 4 ./Testing/ #just to see folder structures, run only on linux systems like colab
# Out:
# ./Testing/
# ├── glioma  [300 entries exceeds filelimit, not opening dir]
# ├── meningioma  [306 entries exceeds filelimit, not opening dir]
# ├── notumor  [405 entries exceeds filelimit, not opening dir]
# └── pituitary  [300 entries exceeds filelimit, not opening dir]
#
# 4 directories, 0 files

# %% [markdown]
# ## Load Dependencies

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix,\
                            classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm
from glob import glob

print('TF Version:', tf.__version__)
# Out:
# TF Version: 2.15.0

# %% [markdown]
# ## Utility functions to create dataset generators

# %%
IMG_DIMS = (128, 128)
BATCH_SIZE = 32
IMG_SHAPE = IMG_DIMS + (3,)
classes = ['glioma', 'meningioma', 'notumor', 'pituitary']

# call this function before running any model to get data into train and validation splits
# data is loaded as a TF dataset in a memory efficient format
def prepare_train_and_val_datasets():
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="training",
        class_names=['glioma', 'meningioma', 'notumor', 'pituitary'],
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="validation",
        class_names=['glioma', 'meningioma', 'notumor', 'pituitary'],
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    train_ds = train_ds.prefetch(buffer_size=25)
    val_ds = val_ds.prefetch(buffer_size=25)

    return train_ds, val_ds

# call this function on any trained model to get prediction labels on the test data
# this loads the test dataset from the test directory as a test dataset
# iterates through the above dataset and returns the true labels as well as the predicted labels
def eval_model_on_test(model):
    test_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Testing",
        class_names=['glioma', 'meningioma', 'notumor', 'pituitary'],
        seed=42,
        image_size=IMG_DIMS,
        batch_size=128,
    )

    test_labels = []
    predictions = []

    for imgs, labels in tqdm(test_ds.take(100),
                             desc='Predicting on Test Data'):
        batch_preds = model.predict(imgs)
        predictions.extend(batch_preds)
        test_labels.extend(labels)

    predictions = np.array(predictions)
    test_labels = np.array(test_labels)

    return test_labels, predictions

# %% [markdown]
# ### Example usage of the above functions
#
# ```
# train_ds, val_ds = prepare_train_and_val_datasets()
#
# model = <BIG CNN MODEL>
#
# history = model.fit(
#     train_ds, epochs=10,
#     validation_data=val_ds,
# )
#
# y_true, y_pred = eval_model_on_test(model)

# %%
train_ds, val_ds = prepare_train_and_val_datasets()
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %%
plt.figure(figsize=(12, 6))

for images, labels in train_ds.take(2):
    for i in range(8):
        ax = plt.subplot(2, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
plt.tight_layout()

# %% [markdown]
# ## If you want to apply data augmentation operations on the train dataset
#
# Go to the `prepare_train_and_val_datasets(...)` and you can add augmentation operations directly to the train dataset as follows:
#
# ```
# train_ds = (train_ds.map(lambda image, label: (tf.image.random_flip_left_right(image), label))
#                     .map(lambda image, label: (tf.image.random_contrast(image, lower=0.2, upper=1.5), label))
#                         .shuffle(2000)
#                         .prefetch(buffer_size=tf.data.AUTOTUNE))
# ```
#
#
# Remember to check [`tf.image`](https://www.tensorflow.org/api_docs/python/tf/image#image_adjustments) for various image transforms available and you can play around with augmentations
#
# __Be careful here and don't add too many transforms which can distort the images beyond recognition__

# %%
train_ds = (train_ds.map(lambda image, label: (tf.image.random_flip_left_right(image), label))
                    .map(lambda image, label: (tf.image.random_contrast(image, lower=0.2, upper=1.5), label))
                        .shuffle(2000)
                        .prefetch(buffer_size=tf.data.AUTOTUNE))

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
print(len(train_ds))
# Out:
# 143

# %%
# here comes the model

# %%
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
train_ds, val_ds = prepare_train_and_val_datasets()  # load and preprocess the train and validation datasets
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %%
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-4087f88952d6> in <cell line: 2>()
#       1 # fit the model to the train dataset using Adam optimizer, cross-entropy loss function, and accuracy metric. also specify callback functions that will be called at certain points during training (such as at the end of each epoch)
# ----> 2 model.fit(train_ds, epochs=50, validation_data=val_ds, verbose=1)  # set the number of epochs to 50, and also specify that we want to save the training log to a CSV file
#       3
#       4 # call the eval_model_on_test function to evaluate the performance of the trained model on the test dataset
#       5 true_labels, predicted_labels = eval_model_on_test(model)  # get the true labels and predicted labels for each image in the test dataset
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1151, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 1209, in compute_loss
#         return self.compiled_loss(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py", line 277, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 143, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 270, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/losses.py", line 2221, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 5573, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None,) and (None, 4, 4, 2048) are incompatible

# %%
y_true, y_pred = eval_model_on_test(model)
# Out:
# Found 1311 files belonging to 4 classes.
# Predicting on Test Data:   0%|          | 0/11 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-68214932f212> in <cell line: 1>()
# ----> 1 y_true, y_pred = eval_model_on_test(model)
#
# <ipython-input-11-8c0bec887831> in eval_model_on_test(model)
#      49     for imgs, labels in tqdm(test_ds.take(100),
#      50                              desc='Predicting on Test Data'):
# ---> 51         batch_preds = model.predict(imgs)
#      52         predictions.extend(batch_preds)
#      53         test_labels.extend(labels)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "efficientnetb0" is incompatible with the layer: expected shape=(None, 224, 224, 3), found shape=(32, 128, 128, 3)

# %%
y_pred_class = np.argmax(y_pred,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-804e0a806285> in <cell line: 1>()
# ----> 1 y_pred_class = np.argmax(y_pred,1)
#
# NameError: name 'y_pred' is not defined

# %%
y_pred_class.shape

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].plot(history.history['sparse_categorical_accuracy'], label='accuracy')
ax[0].plot(history.history['val_sparse_categorical_accuracy'], label = 'val_accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='lower right');

ax[1].plot(history.history['loss'], label='loss')
ax[1].plot(history.history['val_loss'], label = 'val_loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='upper right');

fig.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
class_names=['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
print(classification_report(y_true, y_pred_class, target_names=class_names))

# %%
print(confusion_matrix(y_true, y_pred_class))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-d0aa79341d44> in <cell line: 1>()
# ----> 1 print(confusion_matrix(y_true, y_pred_class))
#
# NameError: name 'y_true' is not defined

# %%
plt.subplots(figsize=(4,3.5))
sns.heatmap(confusion_matrix(y_true, y_pred_class), annot=True, fmt=".0f");
plt.show()

# %%
# basic solution cnn from scratch

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D

IMG_DIMS = (128, 128)
BATCH_SIZE = 32
NUM_CLASSES = 4
EPOCHS = 30

# %%
def prepare_data():
    train_ds, val_ds = prepare_train_val_dataset()
    return train_ds, val_ds

def prepare_train_val_dataset():
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="training",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="validation",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    return train_ds, val_ds

def create_model():
    model = Sequential([
        Conv2D(16, 3, padding='same', activation='relu', input_shape=IMG_SHAPE),
        MaxPooling2D(),
        Conv2D(32, 3, padding='same', activation='relu'),
        MaxPooling2D(),

        Flatten(),
        Dense(NUM_CLASSES) # Output layer has size equal to the number of classes
    ])

    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['sparse_categorical_accuracy'])

    return model

def train_model():
    train_ds, val_ds = prepare_data()
    model = create_model()
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)

if __name__ == "__main__":
    train_model()
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.
# Epoch 1/30
# 143/143 [==============================] - 7s 39ms/step - loss: 11.7321 - sparse_categorical_accuracy: 0.6748 - val_loss: 0.5265 - val_sparse_categorical_accuracy: 0.8214
# Epoch 2/30
# 143/143 [==============================] - 7s 44ms/step - loss: 0.3063 - sparse_categorical_accuracy: 0.8989 - val_loss: 0.3604 - val_sparse_categorical_accuracy: 0.8835
# Epoch 3/30
# 143/143 [==============================] - 5s 37ms/step - loss: 0.1568 - sparse_categorical_accuracy: 0.9538 - val_loss: 0.3313 - val_sparse_categorical_accuracy: 0.8932
# Epoch 4/30
# 143/143 [==============================] - 7s 45ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.3343 - val_sparse_categorical_accuracy: 0.8967
# Epoch 5/30
# 143/143 [==============================] - 5s 36ms/step - loss: 0.0450 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.4208 - val_sparse_categorical_accuracy: 0.9072
# Epoch 6/30
# 143/143 [==============================] - 6s 44ms/step - loss: 0.0322 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.3672 - val_sparse_categorical_accuracy: 0.9107
# Epoch 7/30
# 143/143 [==============================] - 5s 37ms/step - loss: 0.0137 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.3645 - val_sparse_categorical_accuracy: 0.9107
# Epoch 8/30
# 143/143 [==============================] - 6s 44ms/step - loss: 0.0061 - sparse_categorical_accuracy: 0.9996 - val_loss: 0.4210 - val_sparse_categorical_accuracy: 0.9046
# Epoch 9/30
# 143/143 [==============================] - 6s 39ms/step - loss: 0.0033 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4134 - val_sparse_categorical_accuracy: 0.9107
# Epoch 10/30
# 143/143 [==============================] - 5s 36ms/step - loss: 0.0019 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4267 - val_sparse_categorical_accuracy: 0.9098
# Epoch 11/30
# 143/143 [==============================] - 7s 45ms/step - loss: 0.0011 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4458 - val_sparse_categorical_accuracy: 0.9054
# Epoch 12/30
# 143/143 [==============================] - 8s 52ms/step - loss: 8.0978e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4564 - val_sparse_categorical_accuracy: 0.9046
# Epoch 13/30
# 143/143 [==============================] - 5s 37ms/step - loss: 6.4266e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4650 - val_sparse_categorical_accuracy: 0.9063
# Epoch 14/30
# 143/143 [==============================] - 6s 39ms/step - loss: 5.2789e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4759 - val_sparse_categorical_accuracy: 0.9072
# Epoch 15/30
# 143/143 [==============================] - 6s 44ms/step - loss: 4.4286e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4859 - val_sparse_categorical_accuracy: 0.9072
# Epoch 16/30
# 143/143 [==============================] - 5s 37ms/step - loss: 3.7627e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.4934 - val_sparse_categorical_accuracy: 0.9081
# Epoch 17/30
# 143/143 [==============================] - 5s 37ms/step - loss: 3.2437e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5016 - val_sparse_categorical_accuracy: 0.9089
# Epoch 18/30
# 143/143 [==============================] - 7s 46ms/step - loss: 2.8343e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5081 - val_sparse_categorical_accuracy: 0.9089
# Epoch 19/30
# 143/143 [==============================] - 7s 48ms/step - loss: 2.4657e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5151 - val_sparse_categorical_accuracy: 0.9089
# Epoch 20/30
# 143/143 [==============================] - 5s 37ms/step - loss: 2.1945e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5217 - val_sparse_categorical_accuracy: 0.9098
# Epoch 21/30
# 143/143 [==============================] - 6s 37ms/step - loss: 1.9333e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5285 - val_sparse_categorical_accuracy: 0.9089
# Epoch 22/30
# 143/143 [==============================] - 6s 44ms/step - loss: 1.7334e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5352 - val_sparse_categorical_accuracy: 0.9107
# Epoch 23/30
# 143/143 [==============================] - 6s 39ms/step - loss: 1.5288e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5415 - val_sparse_categorical_accuracy: 0.9098
# Epoch 24/30
# 143/143 [==============================] - 7s 44ms/step - loss: 1.3643e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5478 - val_sparse_categorical_accuracy: 0.9089
# Epoch 25/30
# 143/143 [==============================] - 7s 45ms/step - loss: 1.2257e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5520 - val_sparse_categorical_accuracy: 0.9107
# Epoch 26/30
# 143/143 [==============================] - 6s 40ms/step - loss: 1.0965e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5568 - val_sparse_categorical_accuracy: 0.9107
# Epoch 27/30
# 143/143 [==============================] - 7s 45ms/step - loss: 9.8833e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5624 - val_sparse_categorical_accuracy: 0.9089
# Epoch 28/30
# 143/143 [==============================] - 6s 43ms/step - loss: 9.0106e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5677 - val_sparse_categorical_accuracy: 0.9081
# Epoch 29/30
# 143/143 [==============================] - 6s 44ms/step - loss: 8.1748e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5726 - val_sparse_categorical_accuracy: 0.9081
# Epoch 30/30
# 143/143 [==============================] - 6s 39ms/step - loss: 7.3203e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.5777 - val_sparse_categorical_accuracy: 0.9072

# %%
y_true, y_pred = eval_model_on_test(model)
# Out:
# Found 1311 files belonging to 4 classes.
# Predicting on Test Data:   0%|          | 0/11 [00:00<?, ?it/s]
# 4/4 [==============================] - 0s 52ms/step
# Predicting on Test Data:   9%|▉         | 1/11 [00:01<00:13,  1.31s/it]
# 4/4 [==============================] - 0s 32ms/step
# Predicting on Test Data:  18%|█▊        | 2/11 [00:01<00:06,  1.44it/s]
# 4/4 [==============================] - 0s 31ms/step
# Predicting on Test Data:  27%|██▋       | 3/11 [00:01<00:04,  1.96it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  36%|███▋      | 4/11 [00:02<00:02,  2.39it/s]
# 4/4 [==============================] - 0s 30ms/step
# Predicting on Test Data:  45%|████▌     | 5/11 [00:02<00:02,  2.68it/s]
# 4/4 [==============================] - 0s 31ms/step
# Predicting on Test Data:  55%|█████▍    | 6/11 [00:02<00:01,  2.88it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  64%|██████▎   | 7/11 [00:02<00:01,  3.12it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  73%|███████▎  | 8/11 [00:03<00:00,  3.41it/s]
# 4/4 [==============================] - 0s 30ms/step
# Predicting on Test Data:  82%|████████▏ | 9/11 [00:03<00:00,  3.72it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  91%|█████████ | 10/11 [00:03<00:00,  3.95it/s]
# 1/1 [==============================] - 0s 25ms/step
# Predicting on Test Data: 100%|██████████| 11/11 [00:05<00:00,  2.15it/s]

# %%
y_pred_class = np.argmax(y_pred,1)

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right');

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].plot(history.history['accuracy'], label='accuracy')
ax[0].plot(history.history['val_accuracy'], label = 'val_accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='lower right');

ax[1].plot(history.history['loss'], label='loss')
ax[1].plot(history.history['val_loss'], label = 'val_loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='upper right');

fig.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
class_names=['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
print(classification_report(y_true, y_pred_class, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.97      0.82      0.89       300
#   meningioma       0.83      0.92      0.88       306
#      notumor       0.98      1.00      0.99       405
#    pituitary       0.95      0.97      0.96       300
#
#     accuracy                           0.93      1311
#    macro avg       0.93      0.93      0.93      1311
# weighted avg       0.94      0.93      0.93      1311

# %%
print(confusion_matrix(y_true, y_pred_class))
# Out:
# [[247  48   0   5]
#  [  6 283   8   9]
#  [  0   2 403   0]
#  [  2   6   0 292]]

# %%
plt.subplots(figsize=(4,3.5))
sns.heatmap(confusion_matrix(y_true, y_pred_class), annot=True, fmt=".0f");
plt.show()

# %%
'''
#EfficientNetB0
from tensorflow.keras.applications import EfficientNetB0
model = EfficientNetB0(weights='imagenet')
'''
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0.h5
# 21834768/21834768 [==============================] - 0s 0us/step

# %%
'''


def prepare_data():
    train_ds, val_ds = prepare_train_val_dataset()
    return train_ds, val_ds

def prepare_train_val_dataset():
    train_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="training",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    val_ds = tf.keras.preprocessing.image_dataset_from_directory(
        "./Training",
        validation_split=0.2,
        subset="validation",
        seed=42,
        image_size=IMG_DIMS,
        batch_size=BATCH_SIZE,
    )

    return train_ds, val_ds

def create_model():
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    base_model.trainable = False # Freeze the base model by not training it

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(1024, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax'), # Output layer has size equal to the number of classes

        Flatten(),
        Dense(NUM_CLASSES) # Output layer has size equal to the number of classes
    ])

    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    return model

def train_model():
    train_ds, val_ds = prepare_data()
    model = create_model()
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)

if __name__ == "__main__":
    train_model()

'''

# %%
'''
def build_model(num_classes):
    inputs = layers.Input(shape=IMG_SHAPE)
    model = EfficientNetB0(include_top=False, input_tensor=inputs, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )
    return model
    '''

# %%
'''
model = build_model(num_classes=NUM_CLASSES)


history = model.fit(train_ds, epochs=EPOCHS, validation_data=val_ds)
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d9a1f24fdb83> in <cell line: 1>()
# ----> 1 model = build_model(num_classes=NUM_CLASSES)
#       2
#       3
#       4 history = model.fit(train_ds, epochs=EPOCHS, validation_data=val_ds)
#
# NameError: name 'build_model' is not defined

# %%
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0.h5
# 21834768/21834768 [==============================] - 0s 0us/step

# %%
'''
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
base_model.trainable = False # Freeze the base model by not training it

model2 = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(1024, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax') # Output layer has size equal to the number of classes
    ])
# Compile the model
model2.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
'''

# %%
model.summary()

# %%
NUM_CLASSES
# Out:
# 4

# %%
#hist = model2.fit(train_ds, epochs=EPOCHS, validation_data=val_ds)

# %%
#resnet model working
def create_model1():
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=IMG_SHAPE)
    base_model.trainable = False # Freeze the base model by not training it

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(1024, activation='relu'),
        Dense(NUM_CLASSES, activation='softmax') # Output layer has size equal to the number of classes
    ])

   # Compile the model
    model.compile(optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

    return model

# %%
model.summary()

# %%
    model = create_model1()
    history = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS)
# Out:
# Epoch 1/30
# 143/143 [==============================] - 12s 58ms/step - loss: 0.7563 - accuracy: 0.8138 - val_loss: 0.3408 - val_accuracy: 0.8695
# Epoch 2/30
# 143/143 [==============================] - 7s 47ms/step - loss: 0.2495 - accuracy: 0.9044 - val_loss: 0.2618 - val_accuracy: 0.9046
# Epoch 3/30
# 143/143 [==============================] - 8s 53ms/step - loss: 0.1664 - accuracy: 0.9354 - val_loss: 0.1981 - val_accuracy: 0.9282
# Epoch 4/30
# 143/143 [==============================] - 8s 53ms/step - loss: 0.1582 - accuracy: 0.9444 - val_loss: 0.5508 - val_accuracy: 0.8608
# Epoch 5/30
# 143/143 [==============================] - 8s 51ms/step - loss: 0.1128 - accuracy: 0.9630 - val_loss: 0.2030 - val_accuracy: 0.9343
# Epoch 6/30
# 143/143 [==============================] - 7s 49ms/step - loss: 0.0827 - accuracy: 0.9698 - val_loss: 0.2097 - val_accuracy: 0.9299
# Epoch 7/30
# 143/143 [==============================] - 7s 47ms/step - loss: 0.0621 - accuracy: 0.9759 - val_loss: 0.2525 - val_accuracy: 0.9264
# Epoch 8/30
# 143/143 [==============================] - 8s 52ms/step - loss: 0.0671 - accuracy: 0.9746 - val_loss: 0.2138 - val_accuracy: 0.9422
# Epoch 9/30
# 143/143 [==============================] - 8s 53ms/step - loss: 0.0325 - accuracy: 0.9884 - val_loss: 0.2430 - val_accuracy: 0.9343
# Epoch 10/30
# 143/143 [==============================] - 7s 47ms/step - loss: 0.0435 - accuracy: 0.9842 - val_loss: 0.2962 - val_accuracy: 0.9186
# Epoch 11/30
# 143/143 [==============================] - 8s 54ms/step - loss: 0.0537 - accuracy: 0.9807 - val_loss: 0.2156 - val_accuracy: 0.9378
# Epoch 12/30
# 143/143 [==============================] - 8s 52ms/step - loss: 0.0467 - accuracy: 0.9832 - val_loss: 0.3411 - val_accuracy: 0.9212
# Epoch 13/30
# 143/143 [==============================] - 7s 47ms/step - loss: 0.0504 - accuracy: 0.9825 - val_loss: 0.2109 - val_accuracy: 0.9440
# Epoch 14/30
# 143/143 [==============================] - 9s 59ms/step - loss: 0.0236 - accuracy: 0.9928 - val_loss: 0.2448 - val_accuracy: 0.9326
# Epoch 15/30
# 143/143 [==============================] - 8s 53ms/step - loss: 0.0160 - accuracy: 0.9967 - val_loss: 0.2269 - val_accuracy: 0.9431
# Epoch 16/30
# 143/143 [==============================] - 8s 52ms/step - loss: 0.0558 - accuracy: 0.9845 - val_loss: 0.5010 - val_accuracy: 0.8914
# Epoch 17/30
# 143/143 [==============================] - 7s 46ms/step - loss: 0.0792 - accuracy: 0.9724 - val_loss: 0.2836 - val_accuracy: 0.9413
# Epoch 18/30
# 143/143 [==============================] - 8s 57ms/step - loss: 0.0366 - accuracy: 0.9871 - val_loss: 0.2125 - val_accuracy: 0.9413
# Epoch 19/30
# 143/143 [==============================] - 8s 55ms/step - loss: 0.0397 - accuracy: 0.9853 - val_loss: 0.3795 - val_accuracy: 0.9186
# Epoch 20/30
# 143/143 [==============================] - 7s 47ms/step - loss: 0.0314 - accuracy: 0.9891 - val_loss: 0.3067 - val_accuracy: 0.9405
# Epoch 21/30
# 143/143 [==============================] - 8s 52ms/step - loss: 0.0347 - accuracy: 0.9867 - val_loss: 0.2607 - val_accuracy: 0.9405
# Epoch 22/30
# 143/143 [==============================] - 8s 51ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.2442 - val_accuracy: 0.9466
# Epoch 23/30
# 143/143 [==============================] - 7s 47ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 0.1860 - val_accuracy: 0.9632
# Epoch 24/30
# 143/143 [==============================] - 8s 53ms/step - loss: 8.2191e-04 - accuracy: 1.0000 - val_loss: 0.1867 - val_accuracy: 0.9597
# Epoch 25/30
# 143/143 [==============================] - 8s 56ms/step - loss: 4.9160e-04 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9615
# Epoch 26/30
# 143/143 [==============================] - 7s 47ms/step - loss: 3.8111e-04 - accuracy: 1.0000 - val_loss: 0.1914 - val_accuracy: 0.9606
# Epoch 27/30
# 143/143 [==============================] - 7s 47ms/step - loss: 3.2619e-04 - accuracy: 1.0000 - val_loss: 0.1930 - val_accuracy: 0.9615
# Epoch 28/30
# 143/143 [==============================] - 8s 53ms/step - loss: 2.7882e-04 - accuracy: 1.0000 - val_loss: 0.1947 - val_accuracy: 0.9606
# Epoch 29/30
# 143/143 [==============================] - 7s 47ms/step - loss: 2.4948e-04 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9615
# Epoch 30/30
# 143/143 [==============================] - 8s 54ms/step - loss: 2.2499e-04 - accuracy: 1.0000 - val_loss: 0.1982 - val_accuracy: 0.9615

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 128, 128, 16)      448
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 16)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 4)                 131076
#
# =================================================================
# Total params: 136164 (531.89 KB)
# Trainable params: 136164 (531.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# results
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
y_true, y_pred = eval_model_on_test(model)
# Out:
# Found 1311 files belonging to 4 classes.
# Predicting on Test Data:   0%|          | 0/11 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 45ms/step
# Predicting on Test Data:   9%|▉         | 1/11 [00:02<00:21,  2.18s/it]
# 4/4 [==============================] - 0s 38ms/step
# Predicting on Test Data:  18%|█▊        | 2/11 [00:02<00:09,  1.04s/it]
# 4/4 [==============================] - 0s 31ms/step
# Predicting on Test Data:  27%|██▋       | 3/11 [00:02<00:05,  1.49it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  36%|███▋      | 4/11 [00:02<00:03,  2.01it/s]
# 4/4 [==============================] - 0s 28ms/step
# Predicting on Test Data:  45%|████▌     | 5/11 [00:03<00:02,  2.51it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  55%|█████▍    | 6/11 [00:03<00:01,  2.92it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  64%|██████▎   | 7/11 [00:03<00:01,  3.23it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  73%|███████▎  | 8/11 [00:03<00:00,  3.57it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  82%|████████▏ | 9/11 [00:04<00:00,  3.87it/s]
# 4/4 [==============================] - 0s 29ms/step
# Predicting on Test Data:  91%|█████████ | 10/11 [00:04<00:00,  4.11it/s]
# 1/1 [==============================] - 1s 901ms/step
# Predicting on Test Data: 100%|██████████| 11/11 [00:10<00:00,  1.08it/s]

# %%
y_pred_class = np.argmax(y_pred,1)

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
class_names=['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
fig, ax = plt.subplots(1,2, figsize=(7,3))

ax[0].plot(history.history['accuracy'], label='accuracy')
ax[0].plot(history.history['val_accuracy'], label = 'val_accuracy')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='lower right');

ax[1].plot(history.history['loss'], label='loss')
ax[1].plot(history.history['val_loss'], label = 'val_loss')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='upper right');

fig.tight_layout()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right');

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right');

# %%
print(classification_report(y_true, y_pred_class, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.98      0.87      0.92       300
#   meningioma       0.88      0.94      0.91       306
#      notumor       0.99      1.00      0.99       405
#    pituitary       0.95      0.98      0.97       300
#
#     accuracy                           0.95      1311
#    macro avg       0.95      0.95      0.95      1311
# weighted avg       0.95      0.95      0.95      1311

# %%
print(confusion_matrix(y_true, y_pred_class))
# Out:
# [[261  32   0   7]
#  [  5 288   6   7]
#  [  0   2 403   0]
#  [  1   4   0 295]]

# %%
sns.heatmap(confusion_matrix(y_true, y_pred_class), annot=True);
